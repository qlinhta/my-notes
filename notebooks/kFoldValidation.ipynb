# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
from sklearn import linear_model

rcParams.update({'font.size': 18})
plt.rcParams['figure.figsize'] = [12, 12]

# %%
n = 100
L = 4
x = np.linspace(0, L, n)
f = np.power(x, 2)  # parabola with 100 data points

M = 21  # Polynomial degree
phi = np.zeros((n, M))
for j in range(M):
    phi[:, j] = np.power(x, j)  # build matrix A

trials = np.array([2, 10, 100])

fig, axs = plt.subplots(3, 3)

for j in range(len(trials)):
    trial = trials[j]
    E1 = np.zeros(trial)
    E2 = np.zeros(trial)
    E3 = np.zeros(trial)

    A1 = np.zeros((M, trial))
    A2 = np.zeros((M, trial))
    A3 = np.zeros((M, trial))

    for jj in range(trial):
        f = np.power(x, 2) + 0.2 * np.random.randn(n)
        a1 = np.linalg.pinv(np.copy(phi)) @ np.copy(f)
        f1 = phi @ a1
        E1[jj] = np.linalg.norm(f - f1, ord=2) / np.linalg.norm(f, ord=2)

        a2 = np.linalg.lstsq(np.copy(phi), np.copy(f), rcond=None)[0]
        f2 = phi @ a2
        E2[jj] = np.linalg.norm(f - f2, ord=2) / np.linalg.norm(f, ord=2)

        #         regr3 = linear_model.ElasticNet(alpha=1.0, copy_X=True, l1_ratio=0.1, max_iter=10**5,random_state=0)
        regr3 = linear_model.Lasso(alpha=1)
        regr3.fit(phi, f)
        a3 = regr3.coef_
        f3 = phi @ a3
        E3[jj] = np.linalg.norm(f - f3, ord=2) / np.linalg.norm(f, ord=2)

        A1[:, jj] = a1
        A2[:, jj] = a2
        A3[:, jj] = a3

    A1m = np.mean(A1, axis=1)
    A2m = np.mean(A2, axis=1)
    A3m = np.mean(A3, axis=1)

    Err = np.column_stack((E1, E2, E3))

    axs[0, j].bar(range(M), A1m)
    axs[1, j].bar(range(M), A2m)
    axs[2, j].bar(range(M), A3m)

plt.show()
# Out:
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.073e+01, tolerance: 2.301e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.141e+01, tolerance: 2.352e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.166e+01, tolerance: 2.341e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.287e+01, tolerance: 2.355e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.246e+01, tolerance: 2.341e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.183e+01, tolerance: 2.341e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.063e+01, tolerance: 2.334e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.181e+01, tolerance: 2.330e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.246e+01, tolerance: 2.348e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.201e+01, tolerance: 2.344e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.036e+01, tolerance: 2.358e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.188e+01, tolerance: 2.329e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.235e+01, tolerance: 2.317e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.104e+01, tolerance: 2.321e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.230e+01, tolerance: 2.354e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.165e+01, tolerance: 2.318e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.316e+01, tolerance: 2.312e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.157e+01, tolerance: 2.310e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.290e+01, tolerance: 2.300e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.171e+01, tolerance: 2.332e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.234e+01, tolerance: 2.341e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.138e+01, tolerance: 2.302e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.255e+01, tolerance: 2.326e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.088e+01, tolerance: 2.334e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.272e+01, tolerance: 2.338e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.243e+01, tolerance: 2.352e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.252e+01, tolerance: 2.322e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.238e+01, tolerance: 2.301e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.240e+01, tolerance: 2.303e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.058e+01, tolerance: 2.300e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.263e+01, tolerance: 2.354e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.256e+01, tolerance: 2.375e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.297e+01, tolerance: 2.335e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.295e+01, tolerance: 2.352e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.260e+01, tolerance: 2.331e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.242e+01, tolerance: 2.307e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.107e+01, tolerance: 2.326e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.203e+01, tolerance: 2.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.224e+01, tolerance: 2.324e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.592e+01, tolerance: 2.381e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.147e+01, tolerance: 2.343e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.245e+01, tolerance: 2.331e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.158e+01, tolerance: 2.281e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.077e+01, tolerance: 2.328e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.067e+01, tolerance: 2.295e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.226e+01, tolerance: 2.342e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.176e+01, tolerance: 2.326e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.215e+01, tolerance: 2.329e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.305e+01, tolerance: 2.343e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.003e+01, tolerance: 2.302e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.171e+01, tolerance: 2.297e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.155e+01, tolerance: 2.321e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.373e+01, tolerance: 2.320e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.298e+01, tolerance: 2.317e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.091e+01, tolerance: 2.316e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.121e+01, tolerance: 2.336e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.220e+01, tolerance: 2.312e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.079e+01, tolerance: 2.322e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.199e+01, tolerance: 2.330e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.186e+01, tolerance: 2.314e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.175e+01, tolerance: 2.332e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.293e+01, tolerance: 2.338e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.151e+01, tolerance: 2.341e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.041e+01, tolerance: 2.308e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.239e+01, tolerance: 2.338e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.360e+01, tolerance: 2.354e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.091e+01, tolerance: 2.323e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.191e+01, tolerance: 2.338e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.248e+01, tolerance: 2.355e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.214e+01, tolerance: 2.346e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.131e+01, tolerance: 2.305e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.200e+01, tolerance: 2.329e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.294e+01, tolerance: 2.355e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.254e+01, tolerance: 2.321e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.187e+01, tolerance: 2.313e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.155e+01, tolerance: 2.320e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.173e+01, tolerance: 2.368e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.068e+01, tolerance: 2.324e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.337e+01, tolerance: 2.352e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.360e+01, tolerance: 2.334e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.128e+01, tolerance: 2.340e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.007e+01, tolerance: 2.360e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.137e+01, tolerance: 2.317e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.241e+01, tolerance: 2.337e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.104e+01, tolerance: 2.338e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.370e+01, tolerance: 2.317e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.213e+01, tolerance: 2.341e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.224e+01, tolerance: 2.340e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.079e+01, tolerance: 2.309e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.057e+01, tolerance: 2.332e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.200e+01, tolerance: 2.334e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.320e+01, tolerance: 2.341e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.203e+01, tolerance: 2.283e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.299e+01, tolerance: 2.330e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.033e+01, tolerance: 2.343e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.157e+01, tolerance: 2.319e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.213e+01, tolerance: 2.324e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.132e+01, tolerance: 2.317e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.322e+01, tolerance: 2.312e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.209e+01, tolerance: 2.320e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.488e+01, tolerance: 2.348e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.411e+01, tolerance: 2.368e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.093e+01, tolerance: 2.345e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.188e+01, tolerance: 2.294e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.326e+01, tolerance: 2.311e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.242e+01, tolerance: 2.310e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.038e+01, tolerance: 2.313e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.331e+01, tolerance: 2.348e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.253e+01, tolerance: 2.321e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.094e+01, tolerance: 2.351e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.218e+01, tolerance: 2.315e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.125e+01, tolerance: 2.352e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
plt.rcParams['figure.figsize'] = [8, 8]

Atot = np.column_stack((A1m, A2m, A3m))  # Average loadings of three methods
Atot2 = (Atot > 0.2) * Atot  # threshold
Atot3 = np.column_stack((Atot, Atot2))  # combine both thresholded and not

for j in range(3):
    plt.bar(np.arange(Atot.shape[0]) * 4 + j, Atot[:, j], label='A' + str(j + 1) + 'm')

plt.xlim(0, 4 * M)
plt.title('Unthresholded')
plt.legend()

plt.figure()
for j in range(3):
    plt.bar(np.arange(Atot2.shape[0]) * 8 + j, Atot[:, j], label='A' + str(j + 1) + 'm')

plt.title('Thresholded')
plt.xlim(0, 4 * M)
plt.legend()

plt.show()

# %%
n = 200
L = 8
x = np.linspace(0, L, n)
x1 = x[:100]  # Train
x2 = x[100:200]  # Test
n1 = len(x1)
n2 = len(x2)
ftrain = np.power(x1, 2)  # Train parabola x = [0,4]
ftest = np.power(x2, 2)  # Test parabola x = [4,8]

phi_i = np.zeros((n1, M))
phi_e = np.zeros((n2, M))

for j in range(M):
    phi_i[:, j] = np.power(x1, j)  # interpolation key
    phi_e[:, j] = np.power(x2, j)  # extrapolation key

Eni = np.zeros(6)
Ene = np.zeros(6)
for jj in range(6):  # compute inter/extra-polation scores
    ani = Atot3[:, jj]
    fnai = phi_i @ ani
    Eni[jj] = np.linalg.norm(ftrain - fnai, ord=2) / np.linalg.norm(ftrain, ord=2)
    fnae = phi_e @ ani
    Ene[jj] = np.linalg.norm(ftest - fnae, ord=2) / np.linalg.norm(ftest, ord=2)

fig, axs = plt.subplots(2, 2)
axs[0, 0].bar(range(6), Eni)
axs[0, 1].bar(range(6), Ene)
axs[1, 0].bar(range(6), Eni)
axs[1, 0].set_xlim(-0.5, 6.5)
axs[1, 0].set_ylim(0, 0.01)
axs[1, 1].bar(range(6), Ene)
axs[1, 1].set_xlim(-0.5, 6.5)
axs[1, 1].set_ylim(0, 0.1)

plt.show()
