# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Create a dataset 10 features and 10000 values, each with normal distribution
# with mean 0 and standard deviation 1
X = np.random.normal(0, 1, (100, 10))

# %%
df = pd.DataFrame(X, columns=['feature'+str(i) for i in range(1, 11)])

# %%
df
# Out:
#     feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0  -0.483260 -0.129360  0.218459 -0.010651  0.637197  0.187282 -1.141520
# 1   1.783480 -0.960215 -0.386591 -0.095755  0.463601 -0.733780 -0.235316
# 2   0.674663 -0.395641  0.036910 -1.337120  1.088321  1.144027  0.386699
# 3   1.620484  0.098615 -0.651862  0.106558 -0.220413 -1.739451 -0.566807
# 4   0.337991 -0.108419 -0.404616 -0.368729 -0.266969 -0.945754  0.387779
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.441801 -1.077248  1.426365  0.902463  0.081721 -0.902435  0.706455
# 96 -0.366008 -0.872844 -0.195933  0.939203 -0.159603  1.219945 -1.401558
# 97  0.907483 -2.364806 -1.741326  1.763158  1.070949  1.435924 -0.904928
# 98 -0.229806 -1.918567  1.218461 -1.333740  1.026665 -0.030017 -0.648435
# 99 -0.093076 -0.413973  1.647925  0.290731 -0.184696  1.373382  0.955644
#
#     feature8  feature9  feature10
# 0  -3.017155 -0.185502  -2.018979
# ...

# %%
# Plot pair plot of the dataset
def pairplot(df):
    plt.figure(figsize=(10, 10))
    sns.pairplot(df, diag_kind='kde')
    plt.show()

# %%
pairplot(df)

# %%
# Plot heatmap of the correlation matrix of the dataset

def heatmap(df):
    plt.figure(figsize=(10, 10))
    sns.heatmap(df.corr(), annot=True)
    plt.show()

# %%
heatmap(df)

# %%
def scatterplot(df):
    plt.figure(figsize=(10, 10))
    sns.scatterplot(x='feature1', y='feature2', data=df)
    plt.show()

# %%
scatterplot(df)

# %%
def histogram(df):
    plt.figure(figsize=(10, 10))
    sns.distplot(df['feature1'])
    plt.show()

# %%
histogram(df)
# Out:
# /Users/quyenlinhta/.conda/envs/DataAnalysisPSL/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
