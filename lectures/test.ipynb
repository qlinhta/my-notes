# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Create a dataset 10 features and 10000 values, each with normal distribution
# with mean 0 and standard deviation 1
X = np.random.normal(0, 1, (100, 10))

# %%
df = pd.DataFrame(X, columns=['feature'+str(i) for i in range(1, 11)])

# %%
df
# Out:
#     feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0  -3.610036  0.210301 -0.402894 -1.368651  1.194208 -1.778115  2.066500
# 1   1.520308 -0.701710 -0.564613  0.763256 -0.316336 -1.073203  0.856969
# 2   1.116444  0.889110 -0.816980  1.219602  1.253013  0.668579 -1.472741
# 3   0.396506 -0.161312 -0.751919 -0.617726  0.999241  1.499925 -1.811040
# 4   0.365011  0.452265  2.086701  1.427351  0.810496 -1.197164 -0.687423
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.064727 -0.634965 -1.071957 -2.190652 -0.588745  0.565138 -1.003297
# 96  0.450366  1.172927 -0.850207 -0.611398  0.007533  1.922451 -0.430983
# 97  0.145878 -1.210928 -1.195203  0.068429 -2.070864 -0.949825 -0.143769
# 98  1.886120 -1.227179 -0.492142  1.261425 -0.533690 -0.664901 -0.053135
# 99 -0.057007  0.629994  1.114388  1.554287  1.249071  0.735434 -1.225154
#
#     feature8  feature9  feature10
# 0  -0.081156  0.361093   0.102791
# 1   0.400470  2.067247  -1.881471
# 2  -0.352807  0.726496  -1.118126
# 3   1.857319 -1.130324   0.835967
# 4   0.739328 -1.490066   0.862681
# ..       ...       ...        ...
# 95  0.562432 -0.017430  -0.171020
# 96  0.760824  0.927739   0.404363
# 97  1.301535 -0.047026   1.620017
# 98 -1.315588 -0.352401   0.938071
# 99 -0.626938 -0.583733  -0.162670
#
# [100 rows x 10 columns]

# %%
# Plot pair plot of the dataset
def pairplot(df):
    plt.figure(figsize=(10, 10))
    sns.pairplot(df, diag_kind='kde')
    plt.show()

# %%
pairplot(df)

# %%
# Plot heatmap of the correlation matrix of the dataset

def heatmap(df):
    plt.figure(figsize=(10, 10))
    sns.heatmap(df.corr(), annot=True)
    plt.show()

# %%
heatmap(df)
