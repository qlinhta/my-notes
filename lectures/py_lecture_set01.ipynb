# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
matrix = np.random.normal(0, 1, (100, 10))

# %%
matrix
# Out:
# array([[-5.14782799e-01, -1.43451280e-01,  8.65194325e-01,
#         -7.77223328e-01, -4.36704769e-01, -3.63863512e-01,
#          4.36926155e-01, -1.47312920e+00, -2.30809518e-02,
#         -3.67133489e-01],
#        [ 1.14925250e+00,  4.49867847e-01, -6.27110293e-01,
#         -1.19550551e+00, -1.59597715e+00, -1.16819155e+00,
#          3.58846275e-01,  1.59011328e-01, -1.34008454e-01,
#          2.26839515e+00],
#        [ 5.92880517e-01, -9.14925530e-02,  3.52835558e-01,
#         -2.90169702e-01, -1.46267106e-01,  1.23628522e+00,
#          8.34188083e-01, -8.86922654e-02,  9.49733174e-01,
#         -1.97991705e-01],
#        [-8.78923543e-01,  8.31089496e-01, -1.15447024e+00,
#         -7.28162440e-02,  9.89071274e-01,  9.43885712e-02,
#         -1.37845376e-01,  2.75724817e-01,  8.59891524e-01,
#         -9.86427976e-01],
#        [ 8.91813654e-01, -1.34854429e+00,  6.58357598e-01,
#          7.16952026e-01,  6.75526020e-01,  1.51279957e+00,
# ...

# %%
df = pd.DataFrame(matrix)

# %%
def rename_colnames(df):
    for i in range(len(df.columns)):
        df.rename(columns={df.columns[i]: 'Feature' + str(i)}, inplace=True)
    return df

# %%
df = rename_colnames(df)

# %%
df
# Out:
#     Feature0  Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  \
# 0  -0.514783 -0.143451  0.865194 -0.777223 -0.436705 -0.363864  0.436926
# 1   1.149253  0.449868 -0.627110 -1.195506 -1.595977 -1.168192  0.358846
# 2   0.592881 -0.091493  0.352836 -0.290170 -0.146267  1.236285  0.834188
# 3  -0.878924  0.831089 -1.154470 -0.072816  0.989071  0.094389 -0.137845
# 4   0.891814 -1.348544  0.658358  0.716952  0.675526  1.512800  0.275203
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.256793 -0.434820  0.463679  1.735421 -2.073405  2.068429 -0.684612
# 96  0.054645  1.066352 -0.374391 -0.882770  0.987566  0.944058  1.893148
# 97  1.099781 -0.203757  0.685818 -0.679145  0.657955  0.723854  0.211459
# 98 -0.651052 -0.754702  0.046500  0.380491  0.051110 -0.800197  1.193961
# 99 -2.509691  1.066587 -0.916237 -0.553603 -0.383110  0.000272  0.694388
#
#     Feature7  Feature8  Feature9
# 0  -1.473129 -0.023081 -0.367133
# ...

# %%
def heatmap_correlation(df):
    corr = df.corr()
    plt.figure(figsize=(10,10))
    sns.heatmap(corr, annot=True, cmap=plt.cm.Reds)
    plt.show()
    return corr

# %%
heatmap_correlation(df)
# Out:
#           Feature0  Feature1  Feature2  Feature3  Feature4  Feature5  \
# Feature0  1.000000  0.136227  0.140444 -0.034808  0.005535  0.020575
# Feature1  0.136227  1.000000  0.075130 -0.197750 -0.002313 -0.124654
# Feature2  0.140444  0.075130  1.000000  0.050260  0.073648  0.001291
# Feature3 -0.034808 -0.197750  0.050260  1.000000  0.104762  0.078292
# Feature4  0.005535 -0.002313  0.073648  0.104762  1.000000 -0.014366
# Feature5  0.020575 -0.124654  0.001291  0.078292 -0.014366  1.000000
# Feature6  0.045667 -0.068342 -0.073561  0.066997 -0.093410  0.143624
# Feature7 -0.010998  0.067694  0.090659  0.013448 -0.122222 -0.124171
# Feature8 -0.104740  0.048189 -0.123260 -0.139675  0.114129  0.048590
# Feature9  0.174918 -0.058463  0.015469 -0.105459 -0.087308  0.237285
#
#           Feature6  Feature7  Feature8  Feature9
# Feature0  0.045667 -0.010998 -0.104740  0.174918
# Feature1 -0.068342  0.067694  0.048189 -0.058463
# Feature2 -0.073561  0.090659 -0.123260  0.015469
# ...

# %%
def heatmap_correlation_with_mask(df):
    corr = df.corr()
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    plt.figure(figsize=(10,10))
    sns.heatmap(corr, mask=mask, annot=True, cmap=plt.cm.Reds)
    plt.show()
    return corr

# %%
heatmap_correlation_with_mask(df)
# Out:
# /var/folders/sm/lw2bbffs15g5l3r4ldd25hc00000gn/T/ipykernel_16723/2729067792.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
#           Feature0  Feature1  Feature2  Feature3  Feature4  Feature5  \
# Feature0  1.000000  0.136227  0.140444 -0.034808  0.005535  0.020575
# Feature1  0.136227  1.000000  0.075130 -0.197750 -0.002313 -0.124654
# Feature2  0.140444  0.075130  1.000000  0.050260  0.073648  0.001291
# Feature3 -0.034808 -0.197750  0.050260  1.000000  0.104762  0.078292
# Feature4  0.005535 -0.002313  0.073648  0.104762  1.000000 -0.014366
# ...

# %%
def pair_plot(df):
    sns.pairplot(df)
    plt.show()

# %%
pair_plot(df)
