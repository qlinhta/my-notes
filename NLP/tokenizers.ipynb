# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
sentences = ['I like reading books',
             'I am a student',
             'I am based in France',
             'French people is so friendly'
             ]

# %%
tokenizer = Tokenizer(num_words=100, oov_token='<OOV>')

# %%
tokenizer.fit_on_texts(sentences)

# %%
word_index = tokenizer.word_index

# %%
print(word_index)
# Out:
# {'<OOV>': 1, 'i': 2, 'am': 3, 'like': 4, 'reading': 5, 'books': 6, 'a': 7, 'student': 8, 'based': 9, 'in': 10, 'france': 11, 'french': 12, 'people': 13, 'is': 14, 'so': 15, 'friendly': 16}

# %%
new_sentence = ['I love dog', 'I live in Paris']
new_sequence = tokenizer.texts_to_sequences(new_sentence)

# %%
new_sequence
# Out:
# [[2, 1, 1], [2, 1, 10, 1]]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
padding_sequences = pad_sequences(new_sequence)
padding_sequences
# Out:
# array([[ 0,  2,  1,  1],
#        [ 2,  1, 10,  1]], dtype=int32)

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Out:
# --2022-07-22 21:19:17--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.112.128, 74.125.124.128, 172.217.212.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.112.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘sarcasm.json’
#
# sarcasm.json        100%[===================>]   5.38M  --.-KB/s    in 0.04s
#
# 2022-07-22 21:19:17 (154 MB/s) - ‘sarcasm.json’ saved [5643545/5643545]

# %%
import json

with open('sarcasm.json', 'r') as f:
  data = json.load(f)

# %%
for item in data:
  print(item)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'article_link': 'https://local.theonion.com/fourth-grader-drawing-big-blank-on-which-year-9-11-terr-1819576170', 'headline': 'fourth-grader drawing big blank on which year 9/11 terror attacks occurred', 'is_sarcastic': 1}
# {'article_link': 'https://www.theonion.com/nasa-announces-plans-to-launch-chimpanzee-into-sun-1819576704', 'headline': 'nasa announces plans to launch chimpanzee into sun', 'is_sarcastic': 1}
# {'article_link': 'https://www.huffingtonpost.com/entry/revisiting-the-iran-deal_us_59dc089de4b060f005fbd657', 'headline': 'revisiting the iran deal', 'is_sarcastic': 0}
# {'article_link': 'https://politics.theonion.com/arctic-glacier-called-to-melt-before-senate-energy-comm-1819592825', 'headline': 'arctic glacier called to melt before senate energy committee', 'is_sarcastic': 1}
# ...

# %%
sentences = []

for item in data:
  sentences.append(item['headline'])

# %%
sentences
# Out:
# ["former versace store clerk sues over secret 'black code' for minority shoppers",
#  "the 'roseanne' revival catches up to our thorny political mood, for better and worse",
#  "mom starting to fear son's web series closest thing she will have to grandchild",
#  'boehner just wants wife to listen, not come up with alternative debt-reduction ideas',
#  'j.k. rowling wishes snape happy birthday in the most magical way',
#  "advancing the world's women",
#  'the fascinating case for eating lab-grown meat',
#  'this ceo will send your kids to school, if you work for his company',
#  'top snake handler leaves sinking huckabee campaign',
#  "friday's morning email: inside trump's presser for the ages",
#  'airline passengers tackle man who rushes cockpit in bomb threat',
#  'facebook reportedly working on healthcare features and apps',
#  "north korea praises trump and urges us voters to reject 'dull hillary'",
#  "actually, cnn's jeffrey lord has been 'indefensible' for a while",
# ...

# %%
tokenizer = Tokenizer(oov_token='<OOV>')
tokenizer.fit_on_texts(sentences)

# %%
w_index = tokenizer.word_index
w_index
# Out:
# {'<OOV>': 1,
#  'to': 2,
#  'of': 3,
#  'the': 4,
#  'in': 5,
#  'for': 6,
#  'a': 7,
#  'on': 8,
#  'and': 9,
#  'with': 10,
#  'is': 11,
#  'new': 12,
#  'trump': 13,
#  'man': 14,
#  'from': 15,
#  'at': 16,
#  'about': 17,
#  'you': 18,
#  'this': 19,
#  'by': 20,
#  'after': 21,
#  'up': 22,
#  'out': 23,
#  'be': 24,
#  'how': 25,
#  'as': 26,
#  'it': 27,
#  'that': 28,
#  'not': 29,
#  'are': 30,
#  'your': 31,
#  'his': 32,
#  'what': 33,
#  'he': 34,
#  'all': 35,
#  'just': 36,
#  'who': 37,
#  'has': 38,
#  'will': 39,
#  'more': 40,
#  'one': 41,
#  'into': 42,
#  'report': 43,
#  'year': 44,
#  'why': 45,
#  'have': 46,
#  'area': 47,
#  'over': 48,
#  'donald': 49,
#  'u': 50,
#  'day': 51,
#  'says': 52,
#  's': 53,
#  'can': 54,
#  'first': 55,
#  'woman': 56,
#  'time': 57,
#  'like': 58,
#  'her': 59,
#  "trump's": 60,
#  'old': 61,
#  'no': 62,
#  'get': 63,
#  'off': 64,
#  'an': 65,
#  'life': 66,
#  'people': 67,
#  'obama': 68,
#  'now': 69,
#  'house': 70,
# ...

# %%
sequences = tokenizer.texts_to_sequences(sentences)
sequences
# Out:
# [[308, 15115, 679, 3337, 2298, 48, 382, 2576, 15116, 6, 2577, 8434],
#  [4, 8435, 3338, 2746, 22, 2, 166, 8436, 416, 3112, 6, 258, 9, 1002],
#  [145, 838, 2, 907, 1749, 2093, 582, 4719, 221, 143, 39, 46, 2, 10736],
#  [1485, 36, 224, 400, 2, 1832, 29, 319, 22, 10, 2924, 1393, 6969, 968],
#  [767, 719, 4720, 908, 10737, 623, 594, 5, 4, 95, 1309, 92],
#  [10738, 4, 365, 73],
#  [4, 6970, 351, 6, 461, 4274, 2195, 1486],
#  [19, 479, 39, 1168, 31, 155, 2, 99, 83, 18, 158, 6, 32, 352],
#  [249, 3623, 6971, 555, 5274, 1995, 141],
#  [2094, 326, 347, 401, 60, 15117, 6, 4, 3896],
#  [2925, 1680, 4721, 14, 37, 4275, 6972, 5, 2095, 1103],
#  [286, 782, 462, 8, 1556, 1911, 9, 3624],
#  [234, 514, 2926, 13, 9, 929, 226, 369, 2, 4276, 15118, 8437],
#  [238, 3897, 8438, 3339, 38, 235, 15119, 6, 7, 173],
#  [15120, 1394, 665, 651, 5, 327, 3, 1031],
#  [534, 2095, 10739, 123, 10740, 6, 10741, 4722, 1912],
#  [2578,
#   1395,
#   383,
#   45,
#   3898,
#   348,
#   319,
#   1032,
#   2,
#   24,
# ...

# %%
padded = pad_sequences(sequences, padding="post")
padded
# Out:
# array([[  308, 15115,   679, ...,     0,     0,     0],
#        [    4,  8435,  3338, ...,     0,     0,     0],
#        [  145,   838,     2, ...,     0,     0,     0],
#        ...,
#        [10735,     9,    68, ...,     0,     0,     0],
#        [ 1541,   392,  4164, ...,     0,     0,     0],
#        [29656,  1647,     6, ...,     0,     0,     0]], dtype=int32)

# %%
sequences = tokenizer.texts_to_sequences(new_sentence)

# %%
sequences
# Out:
# [[80, 144, 213], [80, 241, 5, 842]]

# %%
pad_sequences(sequences, padding="post")
# Out:
# array([[ 80, 144, 213,   0],
#        [ 80, 241,   5, 842]], dtype=int32)
